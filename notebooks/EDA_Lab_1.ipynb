# %%
import pandas as pd
df = pd.read_csv('Bangalore_Advanced_Ride_Forensics_2.csv')

# %%
df.head(2)

# %%
df.tail(2)

# %%
df.ndim

# %%
df.shape

# %%
df.dtypes

# %%
df.columns

# %%
df.info()

# %%
df.describe()

# %%
df.isnull()

# %%
df.isnull().sum()
